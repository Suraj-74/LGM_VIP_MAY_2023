# %%
import numpy as np
# numpy is aliased as np
import pandas as pd
# pandas is aliased as pd
import matplotlib.pyplot as plt
# pyplot is aliased as plt
import seaborn as sns
# seaborn is aliased as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
# import the data
df=pd.read_csv("C:/Users/Admin/Desktop/Dataset/iris.data")
df.head(10)
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa
# 5  4.6  3.4  1.4  0.3  Iris-setosa
# 6  5.0  3.4  1.5  0.2  Iris-setosa
# 7  4.4  2.9  1.4  0.2  Iris-setosa
# 8  4.9  3.1  1.5  0.1  Iris-setosa
# 9  5.4  3.7  1.5  0.2  Iris-setosa

# %%
# first we have to change the columns name
columns = ['Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Class'] 
# Loadingthe data
df = pd.read_csv('C:/Users/Admin/Desktop/Dataset/iris.data', names=columns)
df.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# checking the shape of the dataset
df.shape
# Out:
# (150, 5)

# %%
# displaying the last 5 rows of the dataset
df.tail()
# Out:
#      Sepal length  Sepal width  Petal length  Petal width           Class
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
# displaying some sample data 
df.sample(6)
# Out:
#      Sepal length  Sepal width  Petal length  Petal width            Class
# 144           6.7          3.3           5.7          2.5   Iris-virginica
# 26            5.0          3.4           1.6          0.4      Iris-setosa
# 140           6.7          3.1           5.6          2.4   Iris-virginica
# 53            5.5          2.3           4.0          1.3  Iris-versicolor
# 116           6.5          3.0           5.5          1.8   Iris-virginica
# 64            5.6          2.9           3.6          1.3  Iris-versicolor

# %% [markdown]
#  ### Data Preprocessing

# %%
# checking the duplicated values
df.duplicated().sum()
# Out:
# 3

# %%
# dropping the duplicated values
df.drop_duplicates(inplace=True)

# %%
#check the duplicated have or not
df.duplicated().any()
# Out:
# False

# %%
# checking the null values 
df.isnull().sum()
# Out:
# Sepal length    0
# Sepal width     0
# Petal length    0
# Petal width     0
# Class           0
# dtype: int64

# %%
# extract categorical column
cat_col=df.select_dtypes(include="object").columns
print(cat_col)
# Out:
# Index(['Class'], dtype='object')

# %%
# displyaing the unique values of the class column
df["Class"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
# displaying the counts of class
df["Class"].value_counts()
# Out:
# Iris-versicolor    50
# Iris-virginica     49
# Iris-setosa        48
# Name: Class, dtype: int64

# %%
# displaying the information about the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 147 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal length  147 non-null    float64
#  1   Sepal width   147 non-null    float64
#  2   Petal length  147 non-null    float64
#  3   Petal width   147 non-null    float64
#  4   Class         147 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.9+ KB

# %%
# displaying the summary of data
df.describe()
# Out:
#        Sepal length  Sepal width  Petal length  Petal width
# count    147.000000   147.000000    147.000000   147.000000
# mean       5.856463     3.055782      3.780272     1.208844
# std        0.829100     0.437009      1.759111     0.757874
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# boxplot for data
df.plot(kind="box", subplots=True, layout=(3,2), figsize=(7,12))
plt.show()

# %%
# histplot for data
df.hist()
plt.show()

# %% [markdown]
# Graphical analysis

# %%
# pie chart for class
a3=df["Class"].value_counts()
a3
# Out:
# Iris-versicolor    50
# Iris-virginica     49
# Iris-setosa        48
# Name: Class, dtype: int64

# %%
# plot a pie graph for class
plt.figure(figsize=(9,8))
plt.pie(a3.values, labels=a3.index, autopct='%.2f%%')
plt.title("class count percentage distribution")
plt.legend()
plt.show()

# %%
# plot a scatter plot for sepal width and sepal length
sns.scatterplot(data=df, x="Sepal width", y="Sepal length", hue="Class")
plt.title("Relation between sepal length and sepal width")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.legend(title='Class',loc='right',bbox_to_anchor=(1,1,0.4,-0.3))
plt.show()

# %%
# plot a scatter plot for petal length and petal width
sns.scatterplot(data=df, x="Petal length", y="Petal width", hue="Class")
plt.title("Relation between sepal length and sepal width")
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()

# %%
# plot a violin plot for class vs sepal length
sns.violinplot(data=df, y='Class', x="Sepal length", inner="quartile")
plt.show()
# plot a violin plot for class vs sepal width
sns.violinplot(data=df, y='Class', x="Sepal width", inner="quartile")
plt.show()
# plot a violin plot for class vs petal length
sns.violinplot(data=df, y='Class', x="Petal length", inner="quartile")
plt.show()
# plot a violin plot for class vs petal width
sns.violinplot(data=df, y='Class', x="Petal width", inner="quartile")
plt.show()

# %%
# find a correlation
corr=df.corr()
corr
# Out:
#               Sepal length  Sepal width  Petal length  Petal width
# Sepal length      1.000000    -0.109321      0.871305     0.817058
# Sepal width      -0.109321     1.000000     -0.421057    -0.356376
# Petal length      0.871305    -0.421057      1.000000     0.961883
# Petal width       0.817058    -0.356376      0.961883     1.000000

# %%
# plot a heatmap for correlation
sns.heatmap(corr, annot=True, cmap="Wistia")
plt.show()

# %%
# plot a pairplot 
sns.pairplot(df, hue='Class', markers='*')
plt.show()

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
la=LabelEncoder()

# %%
df["Class"]=la.fit_transform(df["Class"])
df.head()
# Out:
#    Sepal length  Sepal width  Petal length  Petal width  Class
# 0           5.1          3.5           1.4          0.2      0
# 1           4.9          3.0           1.4          0.2      0
# 2           4.7          3.2           1.3          0.2      0
# 3           4.6          3.1           1.5          0.2      0
# 4           5.0          3.6           1.4          0.2      0

# %% [markdown]
# # Training the model

# %%
# storing the data in x and y variable for training and testing the data
x=df.drop(columns=["Class"])
y=df["Class"]

# %%
# import train_test_split for splliting the data in training and testing form
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test =  train_test_split(x, y, test_size=0.30)

# %%
# displaying the shape of the train and test data
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (102, 4)
# (45, 4)
# (102,)
# (45,)

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
# train the model
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# predicting
Prediction=model.predict(x_test)

# %%
# displaying the prediction
print(Prediction)
# Out:
# [2 0 2 1 1 0 0 1 2 0 1 2 2 0 2 2 1 1 1 1 2 2 2 2 0 2 0 1 2 2 2 2 2 0 2 1 2
#  2 1 1 1 0 0 2 0]

# %% [markdown]
# # Evaluation

# %%
# displatying the confusion matrix
from sklearn.metrics import confusion_matrix
print(confusion_matrix(Prediction, y_test))
# Out:
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  2 19]]

# %%
# to get performance
accuracy=model.score(x_test, y_test)*100
print(accuracy)
# Out:
# 95.55555555555556

# %%
# displaying the classification report
from sklearn.metrics import classification_report
print(classification_report(Prediction,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       0.87      1.00      0.93        13
#            2       1.00      0.90      0.95        21
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.97      0.96        45
# weighted avg       0.96      0.96      0.96        45

# %% [markdown]
# Here this model gives an 95.5% accracy
